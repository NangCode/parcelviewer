# %% [markdown]
# <a href="https://colab.research.google.com/github/NangCode/parcelviewer/blob/main/S2DR3T_infer_20240430.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installation

# %%
# Make sure to select T4 GPU instance from the Runtime/Change-runtime-type menu
# OPTIONAL: Lo link your Google Drive to store output files uncomment and modify the following line
#!ln -s /content/drive/MyDrive/{PATH_TO_OUTPUT_FILES} /content/output
# !pip install -q https://storage.googleapis.com/0x7ff601307fa5/s2dr3-20260724.1-cp312-cp312-linux_x86_64.whl
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.5/26.5 MB 84.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.0/140.0 kB 17.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 125.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 66.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.4/72.4 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 135.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.2/90.2 kB 9.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Inference

# %%
# 1. Install s2dr3 Package
# !pip -q install https://storage.googleapis.com/0x7ff601307fa5/s2dr3-20250905.1-cp312-cp312-linux_x86_64.whl

import os
import glob
import shutil
import s2dr3.inferutils
from google.colab import files

# ==============================================================================
# ⚙️ [INPUT YOUR SETTINGS HERE]
# ==============================================================================
ID = "020-013"  # Single ID used for folder name

LATITUDE = 14.330048896299594
LONGITUDE = 102.9826240639873

DATES_TO_DOWNLOAD = [
    "2026-04-02",
    "2026-04-07",
    "2026-04-12",
    "2026-04-17",
    "2026-04-22",
    "2026-04-27",
]
# ==============================================================================

# Internal variables configured automatically from your single ID
folder_path = f"/content/{ID}"
lonlat = (LONGITUDE, LATITUDE)

# Create folder in Google Colab root sidebar
os.makedirs(folder_path, exist_ok=True)

print(f"=== Starting Processing ===")
print(f"Folder Target: {folder_path}")
print(f"Coordinates: Lat {LATITUDE}, Lon {LONGITUDE}\n")

# Process imagery downloads iteratively
for i, date_str in enumerate(DATES_TO_DOWNLOAD, start=1):
    print(f"[{i}/{len(DATES_TO_DOWNLOAD)}] Processing date: {date_str}...")

    try:
        if os.path.exists('/content/output'):
            shutil.rmtree('/content/output')

        s2dr3.inferutils.test(lonlat, date_str)

        all_tif_files = glob.glob('/content/output/**/*.tif', recursive=True)
        saved = False

        for file_path in all_tif_files:
            file_name = os.path.basename(file_path)
            if 'x10' in file_name.lower() and file_name.lower().endswith('_ms.tif'):
                target_file_path = os.path.join(folder_path, file_name)
                shutil.copy(file_path, target_file_path)
                print(f"   -> Copied into /{ID}/: {file_name}")

                # Automatically download file to your local computer
                # (Your browser will prompt for the save location if enabled)
                files.download(target_file_path)
                print(f"   -> Triggered local download for: {file_name}")
                saved = True

        if not saved:
            print(f"   -> No matching file for date: {date_str}")

    except Exception as e:
        print(f"   -> Error processing date {date_str}: {e}")

print(f"\n==================================================")

# Completion summary
saved_files = os.listdir(folder_path)
if saved_files:
    print(f" Processing complete! {len(saved_files)} file(s) stored in: {folder_path}")
else:
    print(f" Processing complete! No output files found in {folder_path}.")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 52.0 MB/s eta 0:00:00
# === Starting Processing ===
# Folder Target: /content/020-013
# Coordinates: Lat 14.330048896299594, Lon 102.9826240639873
#
# [1/6] Processing date: 2026-04-02...
# Fetching model: 100%|██████████| 829M/829M [00:16<00:00, 50.6MiB/s]
# Fetching data for T48PTA-9e0993482-20260402 .......... done.
# Processing S2L2A_T48PTA-9e0993482-20260402_MS
